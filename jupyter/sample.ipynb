# %%
print ('Hello Jupyter')
# Out:
# Hello Jupyter

# %%
import sys
print(sys.version)
print(sys.path)
# Out:
# 3.8.10 (default, Sep 28 2021, 16:10:42)
# [GCC 9.3.0]
# ['/mnt/c/chihiro/02.github/study_python/jupyter', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/mnt/c/chihiro/02.github/study_python/.venv/lib/python3.8/site-packages', '/mnt/c/chihiro/02.github/study_python/.venv/lib/python3.8/site-packages/IPython/extensions', '/home/chihiro/.ipython']

# %% [markdown]
# # Short cut command
#
# ---
# ## Command Mode
# `m`
# markdown mode
#
# `j k`
# move cell 'down' or 'up'
#
# `a b`
# create cell 'abobe' or 'below'
#
# `dd`
# delete cell
#
# `l`
# view line
#
# ---
# ## Insert Mode
# `Esc`
# exit insert mode
#
# ---
# ## Command and Insert Mode
# `Shift + Enter`
# execute cell

# %%
# ! をつけるとシェルを実行する
# !cat /etc/hosts
# Out:
# # This file was automatically generated by WSL. To stop automatic generation of this file, add the following entry to /etc/wsl.conf:
# # [network]
# # generateHosts = false
# 127.0.0.1	localhost
# 127.0.1.1	aurora-r7.localdomain	aurora-r7
# ﻿
# 192.168.0.15	host.docker.internal
# 192.168.0.15	gateway.docker.internal
# 127.0.0.1	kubernetes.docker.internal
#
# # The following lines are desirable for IPv6 capable hosts
# ::1     ip6-localhost ip6-loopback
# fe00::0 ip6-localnet
# ff00::0 ip6-mcastprefix
# ff02::1 ip6-allnodes
# ff02::2 ip6-allrouters

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.2)
y = np.sin(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x,y)
plt.show()

# %%
# !python -V
# Out:
# Python 3.8.10
